# %% [markdown]
# <a href="https://colab.research.google.com/github/keyraharriee/Project-AI-Computer-vision/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nama = "Zharif"
umur = 19
print("nama saya", nama, "dan umur saya", umur)
# Out:
# nama saya Zharif dan umur saya 19

# %%
nama = input ("sila masukkan nama anda: ")
hobi = input ("Apakah hobi anda: ")
print (f"Oh, {hobi} itu sangat menarik {nama}!")
# Out:
# sila masukkan nama anda: Zharif
# Apakah hobi anda: membaca
# Oh, membaca itu sangat menarik Zharif!

# %%
tahun_lahir = int(input("Tahun Lahir Anda : "))
umur = 2026 - tahun_lahir

print(f"Umur anda pada tahun 2026 ialah {umur} tahun.")
# Out:
# Tahun Lahir Anda : 2007
# Umur anda pada tahun 2026 ialah 19 tahun.

# %%
num1 = int(input("Sila masukkan nombor pertama "))
num2 = int(input("Sila masukkan nombor kedua "))
jumlah = (num1 + num2)

print("Hasil tambah bagi kedua-dua nombor tersebut ialah",jumlah)
# Out:
# Sila masukkan nombor pertama 233
# Sila masukkan nombor kedua 2333
# Hasil tambah bagi kedua-dua nombor tersebut ialah 2566

# %%
mood = input ("Perasaan anda pada hari ini {Happy/Sad}")

if mood == "Happy" :
  print("Teruskan!")

else:
  print("jangan Putus Asa")
# Out:
# Perasaan anda pada hari ini {Happy/Sad}Sad
# jangan Putus Asa

# %%
import random

# Komputer pilih nombor rawak antara 1 hingga 20
nombor_rahsia = random.randint(1, 20)
tekaan = 0

print("Jom main! Saya dah pilih satu nombor antara 1 hingga 20.")

# Gelung akan berjalan selagi tekaan salah
while tekaan != nombor_rahsia:
    tekaan = int(input("Masukkan tekaan anda: "))

    if tekaan < nombor_rahsia:
        print("Terlalu rendah! Cuba lagi.")
    elif tekaan > nombor_rahsia:
        print("Terlalu tinggi! Cuba lagi.")
    else:
        print("Tahniah! Tekaan anda betul! ")
# Out:
# Jom main! Saya dah pilih satu nombor antara 1 hingga 20.
# Masukkan tekaan anda: 5
# Terlalu rendah! Cuba lagi.
# Masukkan tekaan anda: 16
# Terlalu tinggi! Cuba lagi.
# Masukkan tekaan anda: 13
# Terlalu tinggi! Cuba lagi.
# Masukkan tekaan anda: 10
# Terlalu rendah! Cuba lagi.
# Masukkan tekaan anda: 11
# Tahniah! Tekaan anda betul!

# %%
print("--- KALKULATOR UMUR KUCING ---")

# Ambil input nama dan umur kucing
nama_kucing = input("Masukkan nama kucing anda: ")
umur_manusia = input("Masukkan umur kucing tersebut (dalam tahun manusia): ")

# Tukar input teks (str) kepada nombor (int) untuk dikira
umur_int = int(umur_manusia)

# Formula mudah: 1 tahun manusia bersamaan 7 tahun kucing
umur_kucing = umur_int * 7

print(f"Wah, umur {nama_kucing} dalam tahun kucing adalah {umur_kucing} tahun! ")
# Out:
# --- KALKULATOR UMUR KUCING ---
# Masukkan nama kucing anda: Amad
# Masukkan umur kucing tersebut (dalam tahun manusia): 5
# Wah, umur Amad dalam tahun kucing adalah 35 tahun!
